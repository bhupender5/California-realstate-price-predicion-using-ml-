# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Bhupender Singh\Downloads\housing.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.ffill(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       538.461386   1425.476744    499.539680       3.870671
# std        423.516466   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.hist(bins=100,figsize=(15, 15))
plt.show()

# %%
temp_housing1 = df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
temp_housing1['ocena_num'] = encoder.fit_transform(temp_housing1['ocean_proximity'])
temp_housing1 = temp_housing1.drop("ocean_proximity", axis=1) 
temp_housing1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocena_num
# 0       322.0       126.0         8.3252            452600.0          3
# 1      2401.0      1138.0         8.3014            358500.0          3
# 2       496.0       177.0         7.2574            352100.0          3
# 3       558.0       219.0         5.6431            341300.0          3
# 4       565.0       259.0         3.8462            342200.0          3

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(temp_housing1.loc[:, ['median_income', 'total_rooms', 'housing_median_age', 'median_house_value']], dropna=True)
plt.show()

# %%
temp_housing1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
temp_housing1.drop(columns=['longitude','latitude'],inplace=True)

# %%
temp_housing1
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
#        households  median_income  median_house_value  ocena_num
# 0           126.0         8.3252            452600.0          3
# ...

# %%
x = temp_housing1.drop(columns=['median_house_value'])
y = temp_housing1['median_house_value']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
temp_housing1
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
#        households  median_income  median_house_value  ocena_num
# 0           126.0         8.3252            452600.0          3
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("mse:", mse)
print("mae:", mae)
print("rmse:", rmse)
# Out:
# mse: 5929855690.434603
# mae: 56671.32217864922
# rmse: 77005.55623092792

# %%
from sklearn.tree import DecisionTreeRegressor
Decisionmodel = DecisionTreeRegressor(
    max_depth=8,
    min_samples_split=20,
    min_samples_leaf=10,
    random_state=42
)

Decisionmodel.fit(X_train,y_train)
y_pred_decision = Decisionmodel.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred_decision)
mae = mean_absolute_error(y_test, y_pred_decision)
rmse = np.sqrt(mse)

print("mse:", mse)
print("mae:", mae)
print("rmse:", rmse)
# Out:
# mse: 5021864478.674845
# mae: 49570.776522592685
# rmse: 70865.11468046068

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=15,
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rfr = rf.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred_rfr)
mae = mean_absolute_error(y_test, y_pred_rfr)
rmse = np.sqrt(mse)

print("mse:", mse)
print("mae:", mae)
print("rmse:", rmse)
# Out:
# mse: 3998836385.075303
# mae: 43633.50347329619
# rmse: 63236.35335054752

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor()
gb.fit(X_train, y_train)

pred = gb.predict(X_test)


mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("mse:", mse)
print("mae:", mae)
print("rmse:", rmse)
# Out:
# mse: 5929855690.434603
# mae: 56671.32217864922
# rmse: 77005.55623092792

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)
y_predk = gb.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_predk)
mae = mean_absolute_error(y_test, y_predk)
rmse = np.sqrt(mse)

print("mse:", mse)
print("mae:", mae)
print("rmse:", rmse)
# Out:
# mse: 4196380092.5186853
# mae: 45741.664540501064
# rmse: 64779.47277123121
